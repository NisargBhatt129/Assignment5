# %%
#Creating visualization function
def visualize(data01):
    data = pd.read_csv('./data01.csv')
    #Plotting histogram
    data.plot.hist(subplots=True, layout=(5,5), figsize=(20, 20), bins=5)
    matplotlib.pyplot.show()
  
 #Plotting graph for max, mean and min
    plt.plot(data.max())
    plt.plot(data.min())
    plt.plot(data.mean())

# %%
#Creating Stats function
def stat(data01):
    #loading datasets
    data = pd.read_csv('./data01.csv')
    print(data.describe())

# %%
#Loading librarires
import glob
import numpy
import matplotlib
import pandas as pd
import matplotlib.pyplot
import matplotlib.pyplot as plt
import numpy as np

dataset = sorted(glob.glob('data*.csv'))
print(dataset)
# Out:
# ['data01.csv', 'data02.csv', 'data03.csv', 'data04.csv']

# %%
#For loop for task for all dataset
for datasets in dataset[:4]:
    print(datasets)
    
    #printing descrpitive analysis and visualization
    visualize(datasets)
    stat(datasets)
# Out:
# data01.csv
#        feature#1  feature#2  feature#3  feature#4  feature#5
# count        9.0   9.000000   9.000000   9.000000   9.000000
# mean         0.0   0.333333   1.222222   2.111111   2.555556
# std          0.0   0.500000   0.666667   1.054093   1.130388
# min          0.0   0.000000   0.000000   0.000000   1.000000
# 25%          0.0   0.000000   1.000000   2.000000   2.000000
# 50%          0.0   0.000000   1.000000   2.000000   3.000000
# 75%          0.0   1.000000   2.000000   3.000000   3.000000
# max          0.0   1.000000   2.000000   3.000000   4.000000
# data02.csv
#        feature#1  feature#2  feature#3  feature#4  feature#5
# count        9.0   9.000000   9.000000   9.000000   9.000000
# mean         0.0   0.333333   1.222222   2.111111   2.555556
# std          0.0   0.500000   0.666667   1.054093   1.130388
# min          0.0   0.000000   0.000000   0.000000   1.000000
# 25%          0.0   0.000000   1.000000   2.000000   2.000000
# ...
